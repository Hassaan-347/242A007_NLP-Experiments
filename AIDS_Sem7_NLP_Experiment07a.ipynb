# %% [markdown]
# #Experiment 7a
# Hassaan Shaikh
#
# 242A007

# %%
import nltk
from nltk import pos_tag, word_tokenize
from nltk.chunk import RegexpParser

nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
text1 = "Penny visits her brother Thomas at his bakery."
text2 = "The bakery is lively and people of all backgrounds are there."

# %%
tokens = word_tokenize(text2)
tagged = pos_tag(tokens)
print(tagged)
# Out:
# [('The', 'DT'), ('bakery', 'NN'), ('is', 'VBZ'), ('lively', 'RB'), ('and', 'CC'), ('people', 'NNS'), ('of', 'IN'), ('all', 'DT'), ('backgrounds', 'NNS'), ('are', 'VBP'), ('there', 'RB'), ('.', '.')]

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"
chunk_parser = RegexpParser(grammar)
result = chunk_parser.parse(tagged)
print(result)
# Out:
# (S
#   (NP The/DT bakery/NN)
#   is/VBZ
#   lively/RB
#   and/CC
#   people/NNS
#   of/IN
#   all/DT
#   backgrounds/NNS
#   are/VBP
#   there/RB
#   ./.)
