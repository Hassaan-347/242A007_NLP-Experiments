# %% [markdown]
# #NLP Experiment 6
# Hassaan Shaikh
#
# 242A007

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import UnigramTagger, BigramTagger, pos_tag
from nltk.corpus import treebank
from nltk import pos_tag_sents

nltk.download('treebank')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('tagsets_json')
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets_json.zip.
# True

# %%
text = "On his off duty period, enjoying vacation, he met Martha and the two started a new life together. At one point during their life together, he had to leave for another war that was declared on the country. Martha waited patiently for his return, and Arthur did return. Soon, they got married and moved in together, owning a house in Dimen City."
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['On', 'his', 'off', 'duty', 'period', ',', 'enjoying', 'vacation', ',', 'he', 'met', 'Martha', 'and', 'the', 'two', 'started', 'a', 'new', 'life', 'together', '.', 'At', 'one', 'point', 'during', 'their', 'life', 'together', ',', 'he', 'had', 'to', 'leave', 'for', 'another', 'war', 'that', 'was', 'declared', 'on', 'the', 'country', '.', 'Martha', 'waited', 'patiently', 'for', 'his', 'return', ',', 'and', 'Arthur', 'did', 'return', '.', 'Soon', ',', 'they', 'got', 'married', 'and', 'moved', 'in', 'together', ',', 'owning', 'a', 'house', 'in', 'Dimen', 'City', '.']

# %%
rule_based_tag = pos_tag(tokens)
print(rule_based_tag)
# Out:
# [('On', 'IN'), ('his', 'PRP$'), ('off', 'RP'), ('duty', 'NN'), ('period', 'NN'), (',', ','), ('enjoying', 'VBG'), ('vacation', 'NN'), (',', ','), ('he', 'PRP'), ('met', 'VBD'), ('Martha', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('two', 'CD'), ('started', 'VBD'), ('a', 'DT'), ('new', 'JJ'), ('life', 'NN'), ('together', 'RB'), ('.', '.'), ('At', 'IN'), ('one', 'CD'), ('point', 'NN'), ('during', 'IN'), ('their', 'PRP$'), ('life', 'NN'), ('together', 'RB'), (',', ','), ('he', 'PRP'), ('had', 'VBD'), ('to', 'TO'), ('leave', 'VB'), ('for', 'IN'), ('another', 'DT'), ('war', 'NN'), ('that', 'WDT'), ('was', 'VBD'), ('declared', 'VBN'), ('on', 'IN'), ('the', 'DT'), ('country', 'NN'), ('.', '.'), ('Martha', 'NNP'), ('waited', 'VBD'), ('patiently', 'RB'), ('for', 'IN'), ('his', 'PRP$'), ('return', 'NN'), (',', ','), ('and', 'CC'), ('Arthur', 'NNP'), ('did', 'VBD'), ('return', 'VB'), ('.', '.'), ('Soon', 'NNP'), (',', ','), ('they', 'PRP'), ('got', 'VBD'), ('married', 'JJ'), ('and', 'CC'), ('moved'
# ...

# %%
nltk.help.upenn_tagset("PRP$")
# Out:
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your

# %%
train_sents = treebank.tagged_sents()[:3000]

unigram_tagger = UnigramTagger(train_sents)
unigram_tags = unigram_tagger.tag(tokens)

bigram_tagger = BigramTagger(train_sents, backoff = unigram_tagger)
bigram_tags = bigram_tagger.tag(tokens)

print("Unigram Tags: ", unigram_tags)
print("Bigram Tags: ", bigram_tags)
# Out:
# Unigram Tags:  [('On', 'IN'), ('his', 'PRP$'), ('off', 'RP'), ('duty', 'NN'), ('period', 'NN'), (',', ','), ('enjoying', 'VBG'), ('vacation', 'NN'), (',', ','), ('he', 'PRP'), ('met', 'VBD'), ('Martha', None), ('and', 'CC'), ('the', 'DT'), ('two', 'CD'), ('started', 'VBD'), ('a', 'DT'), ('new', 'JJ'), ('life', 'NN'), ('together', 'RB'), ('.', '.'), ('At', 'IN'), ('one', 'CD'), ('point', 'NN'), ('during', 'IN'), ('their', 'PRP$'), ('life', 'NN'), ('together', 'RB'), (',', ','), ('he', 'PRP'), ('had', 'VBD'), ('to', 'TO'), ('leave', 'VB'), ('for', 'IN'), ('another', 'DT'), ('war', 'NN'), ('that', 'IN'), ('was', 'VBD'), ('declared', 'VBD'), ('on', 'IN'), ('the', 'DT'), ('country', 'NN'), ('.', '.'), ('Martha', None), ('waited', 'VBD'), ('patiently', None), ('for', 'IN'), ('his', 'PRP$'), ('return', 'NN'), (',', ','), ('and', 'CC'), ('Arthur', 'NNP'), ('did', 'VBD'), ('return', 'NN'), ('.', '.'), ('Soon', 'RB'), (',', ','), ('they', 'PRP'), ('got', 'VBD'), ('married', None), ('and', 'CC'
# ...

# %%
print("Original text: ")
print(text)
print("\nRule-based Tagging (Statistical):")
print(rule_based_tag)
print("\nDoug was here...")
print("Unigram Tagging:")
print(unigram_tags)
print("\nBigram Tagging:")
print(bigram_tags)
# Out:
# Original text:
# On his off duty period, enjoying vacation, he met Martha and the two started a new life together. At one point during their life together, he had to leave for another war that was declared on the country. Martha waited patiently for his return, and Arthur did return. Soon, they got married and moved in together, owning a house in Dimen City.
#
# Rule-based Tagging (Statistical):
# ...

# %%
test_sents = treebank.tagged_sents()[3000:]
print(f"Accuracy of Unigram Tagger: {unigram_tagger.accuracy(test_sents) * 100:.2f}%")
print(f"Accuracy of Bigram Tagger: {bigram_tagger.accuracy(test_sents) * 100:.2f}%")
# Out:
# Accuracy of Unigram Tagger: 85.72%
# Accuracy of Bigram Tagger: 86.48%
