# %% [markdown]
# #NLP Experiment 3
# Hassaan Shaikh
#
# 242A007
#
# 21/07/2026

# %%
# Import Libraries & Download Resources
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Original Text
text = "The Misadventures of Penny (TMOP) is a semi-serialized, character-driven slice-of-life crime dramedy. The target audience is young adults and upward. In this world where all humans and non-human toons coexist, is Dimen City, a bustling metropolis where people from all walks of life can be met. One such is Penny McCartney, a sharp-tongued, quick-witted legal arms dealer and gunslinger navigating her life along with her best friend Walter Sterling, a tech genius who keeps things logical, and their shared robot companion, 8. Given the crime ridden nature of Dimen City, it is not uncommon to find criminal activity and gangs, the largest of which is The Hooligans. Having committed almost every known crime under the sun, The Hooligans are the vile, scum-of-the-earth, irredeemable monsters. When Penny and her team happen to break one of The Hooligans' major trafficking operations, they find themselves under the crime syndicate's radar and have to balance between work, life, and involuntary vigilantism."
text
# Out:
# "The Misadventures of Penny (TMOP) is a semi-serialized, character-driven slice-of-life crime dramedy. The target audience is young adults and upward. In this world where all humans and non-human toons coexist, is Dimen City, a bustling metropolis where people from all walks of life can be met. One such is Penny McCartney, a sharp-tongued, quick-witted legal arms dealer and gunslinger navigating her life along with her best friend Walter Sterling, a tech genius who keeps things logical, and their shared robot companion, 8. Given the crime ridden nature of Dimen City, it is not uncommon to find criminal activity and gangs, the largest of which is The Hooligans. Having committed almost every known crime under the sun, The Hooligans are the vile, scum-of-the-earth, irredeemable monsters. When Penny and her team happen to break one of The Hooligans' major trafficking operations, they find themselves under the crime syndicate's radar and have to balance between work, life, and involuntary
# ...

# %%
# Text to Lowercase
text_lower = text.lower()
text_lower
# Out:
# "the misadventures of penny (tmop) is a semi-serialized, character-driven slice-of-life crime dramedy. the target audience is young adults and upward. in this world where all humans and non-human toons coexist, is dimen city, a bustling metropolis where people from all walks of life can be met. one such is penny mccartney, a sharp-tongued, quick-witted legal arms dealer and gunslinger navigating her life along with her best friend walter sterling, a tech genius who keeps things logical, and their shared robot companion, 8. given the crime ridden nature of dimen city, it is not uncommon to find criminal activity and gangs, the largest of which is the hooligans. having committed almost every known crime under the sun, the hooligans are the vile, scum-of-the-earth, irredeemable monsters. when penny and her team happen to break one of the hooligans' major trafficking operations, they find themselves under the crime syndicate's radar and have to balance between work, life, and involuntary
# ...

# %%
punctuations = list(string.punctuation)
print(punctuations)
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %%
# Tokenized Text
tokenized_text = word_tokenize(text_lower)
print(tokenized_text)
# Out:
# ['the', 'misadventures', 'of', 'penny', '(', 'tmop', ')', 'is', 'a', 'semi-serialized', ',', 'character-driven', 'slice-of-life', 'crime', 'dramedy', '.', 'the', 'target', 'audience', 'is', 'young', 'adults', 'and', 'upward', '.', 'in', 'this', 'world', 'where', 'all', 'humans', 'and', 'non-human', 'toons', 'coexist', ',', 'is', 'dimen', 'city', ',', 'a', 'bustling', 'metropolis', 'where', 'people', 'from', 'all', 'walks', 'of', 'life', 'can', 'be', 'met', '.', 'one', 'such', 'is', 'penny', 'mccartney', ',', 'a', 'sharp-tongued', ',', 'quick-witted', 'legal', 'arms', 'dealer', 'and', 'gunslinger', 'navigating', 'her', 'life', 'along', 'with', 'her', 'best', 'friend', 'walter', 'sterling', ',', 'a', 'tech', 'genius', 'who', 'keeps', 'things', 'logical', ',', 'and', 'their', 'shared', 'robot', 'companion', ',', '8.', 'given', 'the', 'crime', 'ridden', 'nature', 'of', 'dimen', 'city', ',', 'it', 'is', 'not', 'uncommon', 'to', 'find', 'criminal', 'activity', 'and', 'gangs', ',', 'the', '
# ...

# %%
# Removing Punctuation
cleaned_text1 = []
for word in tokenized_text:
  if word not in punctuations:
    cleaned_text1.append(word)
print(cleaned_text1)
# Out:
# ['the', 'misadventures', 'of', 'penny', 'tmop', 'is', 'a', 'semi-serialized', 'character-driven', 'slice-of-life', 'crime', 'dramedy', 'the', 'target', 'audience', 'is', 'young', 'adults', 'and', 'upward', 'in', 'this', 'world', 'where', 'all', 'humans', 'and', 'non-human', 'toons', 'coexist', 'is', 'dimen', 'city', 'a', 'bustling', 'metropolis', 'where', 'people', 'from', 'all', 'walks', 'of', 'life', 'can', 'be', 'met', 'one', 'such', 'is', 'penny', 'mccartney', 'a', 'sharp-tongued', 'quick-witted', 'legal', 'arms', 'dealer', 'and', 'gunslinger', 'navigating', 'her', 'life', 'along', 'with', 'her', 'best', 'friend', 'walter', 'sterling', 'a', 'tech', 'genius', 'who', 'keeps', 'things', 'logical', 'and', 'their', 'shared', 'robot', 'companion', '8.', 'given', 'the', 'crime', 'ridden', 'nature', 'of', 'dimen', 'city', 'it', 'is', 'not', 'uncommon', 'to', 'find', 'criminal', 'activity', 'and', 'gangs', 'the', 'largest', 'of', 'which', 'is', 'the', 'hooligans', 'having', 'committed', '
# ...

# %%
print(stopwords.words('english'))
print(len(stopwords.words('english')))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
# Removing Stopwords
cleaned_text2 = []
for word in cleaned_text1:
  if word not in stopwords.words('english'):
    cleaned_text2.append(word)
print(cleaned_text2)
# Out:
# ['misadventures', 'penny', 'tmop', 'semi-serialized', 'character-driven', 'slice-of-life', 'crime', 'dramedy', 'target', 'audience', 'young', 'adults', 'upward', 'world', 'humans', 'non-human', 'toons', 'coexist', 'dimen', 'city', 'bustling', 'metropolis', 'people', 'walks', 'life', 'met', 'one', 'penny', 'mccartney', 'sharp-tongued', 'quick-witted', 'legal', 'arms', 'dealer', 'gunslinger', 'navigating', 'life', 'along', 'best', 'friend', 'walter', 'sterling', 'tech', 'genius', 'keeps', 'things', 'logical', 'shared', 'robot', 'companion', '8.', 'given', 'crime', 'ridden', 'nature', 'dimen', 'city', 'uncommon', 'find', 'criminal', 'activity', 'gangs', 'largest', 'hooligans', 'committed', 'almost', 'every', 'known', 'crime', 'sun', 'hooligans', 'vile', 'scum-of-the-earth', 'irredeemable', 'monsters', 'penny', 'team', 'happen', 'break', 'one', 'hooligans', 'major', 'trafficking', 'operations', 'find', 'crime', 'syndicate', "'s", 'radar', 'balance', 'work', 'life', 'involuntary', 'vigila
# ...

# %%
# Stemming
stemmer = PorterStemmer()
stemmed_text = []
for word in cleaned_text2:
  stemmed_text.append(stemmer.stem(word))
print(stemmed_text)
# Out:
# ['misadventur', 'penni', 'tmop', 'semi-seri', 'character-driven', 'slice-of-lif', 'crime', 'dramedi', 'target', 'audienc', 'young', 'adult', 'upward', 'world', 'human', 'non-human', 'toon', 'coexist', 'dimen', 'citi', 'bustl', 'metropoli', 'peopl', 'walk', 'life', 'met', 'one', 'penni', 'mccartney', 'sharp-tongu', 'quick-wit', 'legal', 'arm', 'dealer', 'gunsling', 'navig', 'life', 'along', 'best', 'friend', 'walter', 'sterl', 'tech', 'geniu', 'keep', 'thing', 'logic', 'share', 'robot', 'companion', '8.', 'given', 'crime', 'ridden', 'natur', 'dimen', 'citi', 'uncommon', 'find', 'crimin', 'activ', 'gang', 'largest', 'hooligan', 'commit', 'almost', 'everi', 'known', 'crime', 'sun', 'hooligan', 'vile', 'scum-of-the-earth', 'irredeem', 'monster', 'penni', 'team', 'happen', 'break', 'one', 'hooligan', 'major', 'traffick', 'oper', 'find', 'crime', 'syndic', "'s", 'radar', 'balanc', 'work', 'life', 'involuntari', 'vigilant']

# %%
# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_text = []
for word in cleaned_text2:
  lemmatized_text.append(lemmatizer.lemmatize(word))
print(lemmatized_text)
# Out:
# ['misadventure', 'penny', 'tmop', 'semi-serialized', 'character-driven', 'slice-of-life', 'crime', 'dramedy', 'target', 'audience', 'young', 'adult', 'upward', 'world', 'human', 'non-human', 'toon', 'coexist', 'dimen', 'city', 'bustling', 'metropolis', 'people', 'walk', 'life', 'met', 'one', 'penny', 'mccartney', 'sharp-tongued', 'quick-witted', 'legal', 'arm', 'dealer', 'gunslinger', 'navigating', 'life', 'along', 'best', 'friend', 'walter', 'sterling', 'tech', 'genius', 'keep', 'thing', 'logical', 'shared', 'robot', 'companion', '8.', 'given', 'crime', 'ridden', 'nature', 'dimen', 'city', 'uncommon', 'find', 'criminal', 'activity', 'gang', 'largest', 'hooligan', 'committed', 'almost', 'every', 'known', 'crime', 'sun', 'hooligan', 'vile', 'scum-of-the-earth', 'irredeemable', 'monster', 'penny', 'team', 'happen', 'break', 'one', 'hooligan', 'major', 'trafficking', 'operation', 'find', 'crime', 'syndicate', "'s", 'radar', 'balance', 'work', 'life', 'involuntary', 'vigilantism']

# %%
print("Original Text:")
print(text)
print("\nStemmed Text:")
print(stemmed_text)
print("Doug was here...")
print("\nLemmatized Text:")
print(lemmatized_text)
# Out:
# Original Text:
# ...
