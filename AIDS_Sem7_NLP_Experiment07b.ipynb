# %% [markdown]
# #Experiment 7b
# Hassaan Shaikh
#
# 242A007

# %%
# !pip install svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
nltk.download('tagsets_json')
nltk.download('svgling')

import svgling
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# ...

# %%
text = "In this world where all humans and non-human toons coexist, is Dimen City, a bustling metropolis where people from all walks of life can be met. One such is Penny McCartney, a sharp-tongued, quick-witted legal arms dealer and gunslinger navigating her life along with her best friend Walter Sterling, a tech genius who keeps things logical, and their shared robot companion, 8."

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['In', 'this', 'world', 'where', 'all', 'humans', 'and', 'non-human', 'toons', 'coexist', ',', 'is', 'Dimen', 'City', ',', 'a', 'bustling', 'metropolis', 'where', 'people', 'from', 'all', 'walks', 'of', 'life', 'can', 'be', 'met', '.', 'One', 'such', 'is', 'Penny', 'McCartney', ',', 'a', 'sharp-tongued', ',', 'quick-witted', 'legal', 'arms', 'dealer', 'and', 'gunslinger', 'navigating', 'her', 'life', 'along', 'with', 'her', 'best', 'friend', 'Walter', 'Sterling', ',', 'a', 'tech', 'genius', 'who', 'keeps', 'things', 'logical', ',', 'and', 'their', 'shared', 'robot', 'companion', ',', '8', '.']

# %%
tagged_tokens = pos_tag(tokens)
print(tagged_tokens)
# Out:
# [('In', 'IN'), ('this', 'DT'), ('world', 'NN'), ('where', 'WRB'), ('all', 'DT'), ('humans', 'NNS'), ('and', 'CC'), ('non-human', 'JJ'), ('toons', 'NNS'), ('coexist', 'NN'), (',', ','), ('is', 'VBZ'), ('Dimen', 'NNP'), ('City', 'NNP'), (',', ','), ('a', 'DT'), ('bustling', 'NN'), ('metropolis', 'NN'), ('where', 'WRB'), ('people', 'NNS'), ('from', 'IN'), ('all', 'DT'), ('walks', 'NNS'), ('of', 'IN'), ('life', 'NN'), ('can', 'MD'), ('be', 'VB'), ('met', 'VBN'), ('.', '.'), ('One', 'CD'), ('such', 'JJ'), ('is', 'VBZ'), ('Penny', 'NNP'), ('McCartney', 'NNP'), (',', ','), ('a', 'DT'), ('sharp-tongued', 'JJ'), (',', ','), ('quick-witted', 'JJ'), ('legal', 'JJ'), ('arms', 'NNS'), ('dealer', 'NN'), ('and', 'CC'), ('gunslinger', 'NN'), ('navigating', 'VBG'), ('her', 'PRP$'), ('life', 'NN'), ('along', 'IN'), ('with', 'IN'), ('her', 'PRP$'), ('best', 'JJS'), ('friend', 'NN'), ('Walter', 'NNP'), ('Sterling', 'NNP'), (',', ','), ('a', 'DT'), ('tech', 'JJ'), ('genius', 'NN'), ('who', 'WP'), ('keeps
# ...

# %%
nltk.help.upenn_tagset("CD")
# Out:
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...

# %%
pos_tag(["legal"])
# Out:
# [('legal', 'JJ')]

# %%
named_entities = ne_chunk(tagged_tokens)
print(named_entities)
# Out:
# (S
#   In/IN
#   this/DT
#   world/NN
#   where/WRB
#   all/DT
#   humans/NNS
#   and/CC
#   non-human/JJ
#   toons/NNS
#   coexist/NN
#   ,/,
#   is/VBZ
#   (PERSON Dimen/NNP City/NNP)
#   ,/,
#   a/DT
#   bustling/NN
#   metropolis/NN
#   where/WRB
#   people/NNS
#   from/IN
#   all/DT
#   walks/NNS
#   of/IN
#   life/NN
#   can/MD
#   be/VB
#   met/VBN
#   ./.
#   One/CD
#   such/JJ
#   is/VBZ
#   (PERSON Penny/NNP McCartney/NNP)
#   ,/,
#   a/DT
#   sharp-tongued/JJ
#   ,/,
#   quick-witted/JJ
#   legal/JJ
#   arms/NNS
#   dealer/NN
#   and/CC
#   gunslinger/NN
#   navigating/VBG
#   her/PRP$
#   life/NN
#   along/IN
#   with/IN
#   her/PRP$
#   best/JJS
#   friend/NN
#   (PERSON Walter/NNP Sterling/NNP)
#   ,/,
#   a/DT
#   tech/JJ
#   genius/NN
#   who/WP
#   keeps/VBZ
#   things/NNS
#   logical/JJ
#   ,/,
#   and/CC
#   their/PRP$
#   shared/VBN
#   robot/NN
#   companion/NN
#   ,/,
#   8/CD
#   ./.)

# %%
for subtree in named_entities:
  if isinstance(subtree, nltk.Tree):
    entity = "".join([word for word, tag in subtree.leaves()])
    label = subtree.label()
    print(f"Entity: {entity}, Label: {label}")
# Out:
# Entity: DimenCity, Label: PERSON
# Entity: PennyMcCartney, Label: PERSON
# Entity: WalterSterling, Label: PERSON

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp(text)
for ent in doc.ents:
  print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Entity: Dimen City, Label: GPE
# Entity: One, Label: CARDINAL
# Entity: Penny McCartney, Label: PERSON
# Entity: Walter Sterling, Label: PERSON
# Entity: 8, Label: CARDINAL
