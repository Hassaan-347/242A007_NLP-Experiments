# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string

nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('stopwords')

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
text = "The runner is running fast."

# %%
text_lower = text.lower()
print(text_lower)
# Out:
# the runner is running fast.

# %%
tokens = word_tokenize(text_lower)
print(tokens)
# Out:
# ['the', 'runner', 'is', 'running', 'fast', '.']

# %%
text_clean1 = [token for token in tokens if token not in string.punctuation]
print(text_clean1)
# Out:
# ['the', 'runner', 'is', 'running', 'fast']

# %%
lemmatizer = WordNetLemmatizer()
text_clean2 = [lemmatizer.lemmatize(token, pos = 'v') for token in text_clean1]
print(text_clean2)
# Out:
# ['the', 'runner', 'be', 'run', 'fast']

# %%
lemmatizer.lemmatize('catcher', pos = 'n')
# Out:
# 'catcher'

# %%
[(token, lemma) for token, lemma in zip(tokens, text_clean2)]
# Out:
# [('the', 'the'),
#  ('runner', 'runner'),
#  ('is', 'be'),
#  ('running', 'run'),
#  ('fast', 'fast')]

# %%
morphological_info = {}
for token, lemma in zip(tokens, text_clean2):
    if token != lemma:
      if token.endswith("ing"):
        analysis = f"Inflectional: Present participle/continuous form of '{lemma}'."
      elif token.endswith("er"):
        analysis = f"Derivational: '{lemma}' + er -> person who does an action."
      else:
        analysis = f"Inflectional or irregular form of '{lemma}'."
    else:
      analysis = "Base/Root form."
    morphological_info[token] = analysis

morphological_info
# Out:
# {'the': 'Base/Root form.',
#  'runner': 'Base/Root form.',
#  'is': "Inflectional or irregular form of 'be'.",
#  'running': "Inflectional: Present participle/continuous form of 'run'.",
#  'fast': 'Base/Root form.'}

# %%
print("Original text:", text)
print("Lowercase text:", text_lower)
print("Tokenized text:", tokens)
print("Cleaned text:", text_clean1)
print("Lemmatized text:", text_clean2)
# Out:
# Original text: The runner is running fast.
# Lowercase text: the runner is running fast.
# Tokenized text: ['the', 'runner', 'is', 'running', 'fast', '.']
# Cleaned text: ['the', 'runner', 'is', 'running', 'fast']
# Lemmatized text: ['the', 'runner', 'be', 'run', 'fast']
